# %% [markdown]
# Ishan Dubey
# Dept. of CSE
# Ramaiah Institute of Technology

# %%
# %%capture
# !pip install transformers

# %%
import re
import requests

import numpy as np
import pandas as pd

import torch
from transformers import pipeline
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# HuggingFace pipeline for Sentiment Analysis
sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")

# Downloads and sets up model trained on BBC News dataset
model = AutoModelForSequenceClassification.from_pretrained("abhishek/autonlp-bbc-news-classification-37229289")
tokenizer = AutoTokenizer.from_pretrained("abhishek/autonlp-bbc-news-classification-37229289")
# Out:
# Downloading:   0%|          | 0.00/687 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/963 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/311 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def get_news():
  # Function to query NewsAPI. Returns a list of article titles and their description

  # NewsAPI setup
  query_params = {
      "source": "The Indian Express",
      "sortBy": "top",
      "apiKey": "540e7fbdd83349cb93414db46d36c6f3", # API Limit is 100 requests per day
  }
  main_url = "https://newsapi.org/v2/top-headlines?country=in"
  
  # Get top articles from newsAPI
  res = requests.get(main_url, params=query_params)
  content = res.json()

  articles = content['articles']

  titles = list()
  article_text = list()
  for article in articles:
    titles.append(article['title'])
    article_text.append(article['description']) 
  
  return titles, article_text

def analyse_sentiment(text): 
  # Performs sentiment Analysis using a fine-tune RoBERTa Model

  return sentiment_analysis(text)

def find_topic(title):
  # Uses a transformer model to classify article into the topics, trained on BBC news dataset
  
  id2label = {0:'business', 1:'entertainment', 2:'politics', 3:'sport', 4:'tech'}
  inputs = tokenizer(title, return_tensors="pt")
  outputs = model(**inputs)
  topic = id2label[torch.argmax(outputs.logits).item()]
  return topic

# %%
output = list()

#Query the API to obtain the dataset
titles, articles = get_news()

#Perform sentiment analysis
for title, article_text in zip(titles, articles):
  sentiment = analyse_sentiment(str(article_text))
  topic = find_topic(title)
  output.append((title, article_text, sentiment[0]['label'], sentiment[0]['score'], topic))

#Output the results
df = pd.DataFrame(output, columns=['title','article_text', 'sentiment', 'confidence', 'topic'])
df[:]
# Out:
#                                                 title  \
# 0   Research explains how plants optimise photosyn...
# 1   Samsung in 2023: Predictions, rumors, and what...
# 2   ACV Keto Gummies {Shocking US & CA Customer Re...
# 3   UP Opposition To Stay Away From Congress Yatra...
# 4   Samsung Galaxy S22 FE is not dead! Could get S...
# 5   New Gigabyte G5 gaming laptops launched in Ind...
# 6   For Salman Khan, Birthday Wish From Sister Arp...
# 7   Ethnic Serbs erect more roadblocks as tensions...
# 8   Tunisha Sharma Suicide Case LIVE Updates: Actr...
# 9   Unadkat: Getting a Test wicket is something I ...
# 10  "Itni Tabahi Hui Hai...": Najam Sethi Having '...
# 11  Increasing global warming and light pollution ...
# 12  China gives up reporting Covid-19 figures as v...
# 13  NASA's Hubble Space Telescope Captures Milky W...
# 14  Wonders Of Space: Best Photos Clicked By James...
# 15  After Allahabad HC order on civic elections, G...
# 16  PM Modi's brother Prahlad's car meets with acc...
# 17  Delhi colder than Nainital today amid severe c...
# 18  Alert! WhatsApp to stop working on THESE old p...
# 19  HDFC Bank hikes bulk FD rates, senior citizens...
#
#                                          article_text sentiment  confidence  \
# 0   For research, plants are frequently grown unde...  POSITIVE    0.998720
# 1                                                None  NEGATIVE    0.997574
# 2   The many health benefits of apple cider vinega...  POSITIVE    0.998744
# 3   Rahul Gandhi's Bharat Jodo Yatra might draw a ...  POSITIVE    0.985397
# 4   Samsung Galaxy S22 FE is now tipped to launch ...  POSITIVE    0.993227
# 5   Gigabyte's new gaming laptops come powered by ...  POSITIVE    0.998096
# 6   "Happiest Birthday to my life line," wrote Arp...  POSITIVE    0.998883
# 7   Kosovo has demanded barriers erected by Serb p...  NEGATIVE    0.997758
# 8   Tunisha Sharma Death Live Updates: Shivin Nara...  POSITIVE    0.995593
# 9   The India fast bowler reflects on his Test com...  POSITIVE    0.997454
# 10  A 14-member committee, headed by Najam Sethi, ...  POSITIVE    0.979575
# 11  If you reside within the confines of bumbling ...  NEGATIVE    0.997017
# 12  "As of today, we will no longer release daily ...  NEGATIVE    0.994909
# 13  The data in this image come from two different...  POSITIVE    0.997304
# 14  The James Webb Space Telescope (JWST) has chan...  POSITIVE    0.998605
# 15  The government said in a statement local body ...  NEGATIVE    0.982079
# 16  The Mercedes Benz car in which Prahlad Modi, b...  NEGATIVE    0.998457
# 17  The lowest minimum temperature in Delhi was re...  NEGATIVE    0.997370
# 18  Software update is an indispensable part that ...  POSITIVE    0.998661
# 19  The largest private sector lender HDFC Bank ha...  NEGATIVE    0.997719
#
#             topic
# 0            tech
# 1            tech
# 2           sport
# 3        politics
# 4            tech
# 5            tech
# 6   entertainment
# 7        business
# 8   entertainment
# 9           sport
# 10  entertainment
# 11           tech
# 12           tech
# 13           tech
# 14           tech
# 15       politics
# 16       politics
# 17  entertainment
# 18           tech
# 19       business
